# %%
import pandas as pd
import numpy as np
import sklearn
from matplotlib import pyplot as plt

# %%
df=pd.read_csv("trial_plot.csv")
df.head(11)
bp=df["bp"]
methelyne=["mu"]

# %%
plt.scatter(df.mu,df.bp, marker=".", color= "red")
plt.xlabel("No of Methylene Units")
plt.ylabel("Boiling Points")
# Out:
# Text(0, 0.5, 'Boiling Points')
